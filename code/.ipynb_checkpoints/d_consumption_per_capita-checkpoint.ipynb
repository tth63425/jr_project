# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../data/raw/domestic/d_2019_1-3.xlsx', sheet_name=1)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df
# Out:
#   23071           …      0.0068       29249
# 49      0.0034       14887           …      0.0053       19015
# 50      0.0021       26278           …      0.0025        9971
# 51      0.0098       15306           …      0.0067       30000
# 52           -           -           …           0       50213
# 53           …           …           …           …           …
# 54           …           …           …           …           …
# 55           …           …           …           …           …
# 56           …           …           …           …           …
# 57           …           …           …           …           …
# 58           …           …           …           …           …
# 59         NaN         NaN         NaN         NaN         NaN
# 60         NaN         NaN         NaN         NaN         NaN
#
#    旅行種類(2区分)，宿泊の有無(2区分)，旅行目的(3区分)，\n旅行時期(月)・男女(2区分)，年齢(9区分)・居住地(10区分)・主目的地(16区分)別 旅行経験率・旅行平均回数・旅行単価・平均泊数.2  \
# 0                                                 NaN
# ...

# %%
trip_type = ['one-day','stay']
trip_purpose = ['total','tourism','retun home','bussiness trip']
month = ['first','second','third']
sex = ['female','male']
age = ['9-','10','20','30','40','50','60','70','80+']
home_place = ['Hokkaido','Tohoku','Kanto','Hokuriku','Chubu','Kinki','Chugoku','Shikoku','Kyusyu','Okinawa']
place_purpose = ['Hokkaido','Tohoku','Kanto','Hokuriku','Chubu','Kinki','Chugoku','Shikoku','Kyusyu','Okinawa']

# %%
for i in range(6,52):
# Out:
# 8
