# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../data/raw/domestic/d_2019_1-3.xlsx', sheet_name=20)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df
# Out:
#       参考4　 宿泊の有無(2区分)，旅行目的(3区分)，\n主目的地(47区分)別 延べ旅行者数 ─ 国内旅行   Unnamed: 2  \
# 0      NaN                                              NaN          NaN
# 1      NaN                                             宿泊旅行          NaN
# 2      NaN                                              NaN  観光・レクリエーション
# 3     主目的地                                          64045.7      35188.5
# 4     　北海道                                          2938.02      1866.38
# 5      　東北                                          4332.13      1897.18
# 6    　　青森県                                          620.361      133.937
# 7    　　岩手県                                          836.203       238.42
# 8    　　宮城県                                            692.7      427.118
# 9    　　秋田県                                          462.922       70.892
# 10   　　山形県                                          557.416      324.428
# 11   　　福島県                                          1162.53       702.38
# ...
