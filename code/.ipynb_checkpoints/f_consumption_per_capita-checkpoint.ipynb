# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../data/raw/foreign/f_2018_1-3.xls', sheet_name=30)

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                           2018年（平成30年）  1-3月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                             日本滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
prefs = ["Hokkaido",'Aomori','Iwate','Miyagi','Akita','Yamagata','Fukushima','Ibaraki','Tochigi',
                 'Gumma','Saitama','Chiba','Tokyo','Kanagawa','Niigata','Toyama','Ishikawa','Fukui',
                 'Yamanashi','Nagano','Gifu','Shizuoka','Aichi','Mie','Shiga','Kyoto','Osaka','Hyogo','Nara',
                 'Wakayama','Tottori','Shimane','Okayama','Hiroshima','Yamaguchi',
                 'Tokushima','Kagawa','Ehime','Kochi','Fukuoka','Saga','Nagasaki','Kumamoto','Oita','Miyazaki','Kagoshima','Okinawa']

# %%
item = ["Group Package", "Individual Package", "Rouund-trip Air / Ship", "Accommodation", "Food",
        "Transportation - Overall", "Transportation - Train", "Transportation - Bus/Taxi",
        "Transportation - Others", "Leisure", "Shopping", "Others"]

# %%
# Group package

dict_all = []

for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        answers = df.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        consumption = df.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        dict_row = {"Year": 2018, "Quarter": 1, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
        dict_all.append(dict_row)

# %%
df_2018_2q = pd.read_excel('../data/raw/foreign/f_2018_4-6.xls', sheet_name=30)

# %%
df_2018_2q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                           2018年（平成30年）  4-6月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                             日本滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2018_2q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2018_2q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2018, "Quarter": 2, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}

        dict_all.append(dict_row)

# %%
len(dict_all)
# Out:
# 1128

# %%
df_2018_3q = pd.read_excel('../data/raw/foreign/f_2018_7-9.xls', sheet_name=30)

# %%
df_2018_3q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                           2018年（平成30年）  7-9月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                             日本滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2018_3q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2018_3q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2018, "Quarter": 3, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
        dict_all.append(dict_row)

# %%
df_2018_4q = pd.read_excel('../data/raw/foreign/f_2018_10-12.xls', sheet_name=30)

# %%
df_2018_4q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                         2018年（平成30年）  10-12月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                             日本滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2018_4q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2018_4q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2018, "Quarter": 4, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
#         print(dict_row)
        dict_all.append(dict_row)

# %%
df_2019_1q = pd.read_excel('../data/raw/foreign/f_2019_1-3.xls', sheet_name=30)

# %%
df_2019_1q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                                    2019年1-3月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                               滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2019_1q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2019_1q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2019, "Quarter": 1, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
#         print(dict_row)
        dict_all.append(dict_row)

# %%
df_2019_2q = pd.read_excel('../data/raw/foreign/f_2019_4-6.xls', sheet_name=30)
df_2019_2q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                                    2019年4-6月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                               滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2019_2q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2019_2q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2019, "Quarter": 2, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
#         print(dict_row)
        dict_all.append(dict_row)

# %%
df_2019_3q = pd.read_excel('../data/raw/foreign/f_2019_7-9.xls', sheet_name=30)
df_2019_3q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                                    2019年7-9月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                               滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2019_3q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2019_3q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2019, "Quarter": 3, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
#         print(dict_row)
        dict_all.append(dict_row)

# %%
df_2019_4q = pd.read_excel('../data/raw/foreign/f_2019_10-12.xls', sheet_name=30)
df_2019_4q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                                  2019年10-12月期　【確報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                               滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2019_4q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2019_4q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2019, "Quarter": 4, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
#         print(dict_row)
        dict_all.append(dict_row)

# %%
df_2020_1q = pd.read_excel('../data/raw/foreign/f_2020_1-3.xls', sheet_name=30)
df_2020_1q
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  参考13　訪問地（都道府県47区分および地方運輸局等10区分）別　費目別購入率および購入者単...
# 1          NaN                                                NaN
# 2          NaN                                  2020年1-3月期　【２次速報】
# 3          NaN                                               調査項目
# 4          NaN                                                NaN
# 5          NaN                                              旅行前支出
# 6          NaN                                               【B1】
# 7          NaN                                                NaN
# 8          NaN                                               滞在中の
# 9          NaN                                              費目別支出
# 10         NaN                                               【B1】
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
for j in range(20,32):
    
    row_info = []
    
    item_j = item[j - 20]
#     print(item_j)


    # Number of Answers
    answers_all = []
    consumption_all = []

    for i in range(4,98,2):
        # CHANGE ##############################################
        answers = df_2020_1q.iloc[j,i]
        answers_all.append(answers)
        keynumber = int((i / 2) - 2)

    # Comsumption per capita
    for i in range(5,99,2):
        # CHANGE ##############################################
        consumption = df_2020_1q.iloc[j,i]
        consumption_all.append(consumption)
        
    for i in range(47):
        answer_pref = answers_all[i]
        consumption_pref = consumption_all[i]
        pref = prefs[i]
        
        if answer_pref == 0:
            consumption_pref = 0
        
        # CHANGE ##############################################
        dict_row = {"Year": 2020, "Quarter": 1, "Pref": pref, "Item": item_j, "Answers": answer_pref, "Consumption": consumption_pref}
#         print(dict_row)
        dict_all.append(dict_row)

# %%
len(dict_all)
# Out:
# 5076

# %%
df_all = pd.DataFrame(dict_all)

# %%
df_all
# Out:
#       Year  Quarter       Pref           Item  Answers  Consumption
# 0     2018        1   Hokkaido  Group Package      637  151043.6343
# 1     2018        1     Aomori  Group Package       12  133212.6016
# 2     2018        1      Iwate  Group Package       16  145751.7647
# 3     2018        1     Miyagi  Group Package       58  150746.8557
# 4     2018        1      Akita  Group Package       14  151616.2406
# ...    ...      ...        ...            ...      ...          ...
# 5071  2020        1   Kumamoto         Others        4    1258.2546
# 5072  2020        1       Oita         Others        3    1126.7797
# 5073  2020        1   Miyazaki         Others        0       0.0000
# 5074  2020        1  Kagoshima         Others        6     807.6999
# 5075  2020        1    Okinawa         Others        6    2488.0481
#
# [5076 rows x 6 columns]

# %%
df_all.to_csv("../csv/for_analysis/raw.csv")
